# %%
# Set-up statements that we will nearly always use
import numpy as np
import pandas as pd
import matplotlib.pyplot as pl
# %matplotlib inline

# %% [markdown]
# # A very quick look at some real data

# %%
# ecoli = pd.read_csv('~/Dropbox/Transfer/Teaching/DATA201/Datasets/TaranakiStWharf.csv',skiprows=0,header=None,parse_dates=[8])
ecoli = pd.read_csv('../../res/data/../../res/data/TaranakiStWharf.csv', skiprows=0, header=None, parse_dates=[8])

# %% [markdown]
# What does it look like?

# %%
ecoli.head()
# Out:
#                   0                                                1      2   \
# 0  Wellington region  Wellington Harbour at Taranaki St Dive Platform  Beach
# 1  Wellington region  Wellington Harbour at Taranaki St Dive Platform  Beach
# 2  Wellington region  Wellington Harbour at Taranaki St Dive Platform  Beach
# 3  Wellington region  Wellington Harbour at Taranaki St Dive Platform  Beach
# 4  Wellington region  Wellington Harbour at Taranaki St Dive Platform  Beach
#
#          3          4           5            6   7                   8   9   \
# 0  GW-10079 -41.289842  174.780547  Enterococci   0 2016-05-12 09:15:00  20
# 1  GW-10079 -41.289842  174.780547  Enterococci   0 2016-12-12 07:12:00  16
# 2  GW-10079 -41.289842  174.780547  Enterococci   0 2016-12-19 08:45:00  12
# 3  GW-10079 -41.289842  174.780547  Enterococci   0 2016-12-26 08:06:00   4
# 4  GW-10079 -41.289842  174.780547  Enterococci   0 2017-02-01 09:16:00  28
#
#       10                                                 11
# 0  Green  LAWA Partners shall not be liable, whether in ...
# 1  Green  LAWA Partners shall not be liable, whether in ...
# 2  Green  LAWA Partners shall not be liable, whether in ...
# 3  Green  LAWA Partners shall not be liable, whether in ...
# 4  Green  LAWA Partners shall not be liable, whether in ...

# %% [markdown]
# How do we plot the ecoli data?

# %%
pl.plot(ecoli[9])

# %% [markdown]
# It would be more useful with a better $x$ axis

# %%
pl.plot(ecoli[8], ecoli[9], '.')

# %% [markdown]
# Accessing some parts of the data

# %%
ecoli.loc[0:5,8:9]
# Out:
#                     8   9
# 0 2016-05-12 09:15:00  20
# 1 2016-12-12 07:12:00  16
# 2 2016-12-19 08:45:00  12
# 3 2016-12-26 08:06:00   4
# 4 2017-02-01 09:16:00  28
# 5 2017-09-01 11:20:00  24

# %% [markdown]
# There are colours associated with these, to say if you can swim -- red if ecoli > 350, amber if it is > 150, green otherwise

# %%
pl.plot(ecoli.iloc[:,8],ecoli.iloc[:,9],'.g',markersize=10)

inds_amber = np.squeeze(np.where((ecoli.iloc[:,9] > 150) & (ecoli.iloc[:,9] < 350)))
inds_red = np.squeeze(np.where(ecoli.iloc[:,9] > 350))

pl.plot(ecoli.iloc[inds_amber,8],ecoli.iloc[inds_amber,9],'.k',markersize=10)
pl.plot(ecoli.iloc[inds_red,8],ecoli.iloc[inds_red,9],'.r',markersize=10)

# %% [markdown]
# And if you think some of those numbers are bad...
# https://www.lawa.org.nz/explore-data/wellington-region/coastal/wellington-harbour-at-taranaki-st-dive-platform/

# %% [markdown]
# # In case that was too cheery

# %%
#co2 = pd.read_csv('~/Dropbox/Transfer/Teaching/DATA201/Datasets/MLO/mlo_station/daily_flask_co2_mlo.csv',skiprows=70,header=None,parse_dates=[0])
co2 = pd.read_csv('../../res/data/daily_flask_co2_mlo.csv', skiprows=70, header=None, parse_dates=[0])
co2.head()
# Out:
#            0       1         2         3  4  5       6
# 0 1960-03-31   16:00  22006.67  1960.248  2  0  318.29
# 1 1960-04-23   10:30  22029.44  1960.310  3  4  318.61
# 2 1960-04-24   08:00  22030.33  1960.312  3  0  319.33
# 3 1960-07-03   15:20  22100.64  1960.504  2  4  320.35
# 4 1960-07-17   17:00  22114.71  1960.543  2  4  315.95

# %% [markdown]
# This is the CO2 (in ppm) at Mauna Loa on Hawaii for the 60 or so years. Let's plot it.

# %%
pl.plot(co2.iloc[:,0], co2.iloc[:,-1])

# %% [markdown]
# Does it match the NZ data? Let's get that and plot them both.

# %%
#co2nz = pd.read_csv('~/Dropbox/Transfer/Teaching/DATA201/Datasets/daily_flask_co2_nzd.csv',skiprows=70,header=None,parse_dates=[0])
co2nz = pd.read_csv('../../res/data/daily_flask_co2_nzd.csv', skiprows=70, header=None, parse_dates=[0])

# %%
pl.plot(co2nz.iloc[:,-1])
pl.plot(co2.iloc[:,-1], 'r')

# %% [markdown]
# Why don't they match?

# %%
pl.plot(co2nz.iloc[:,0], co2nz.iloc[:,-1])
pl.plot(co2.iloc[:,0], co2.iloc[:,-1])

# %%
pl.plot(co2nz.iloc[500:,0], co2nz.iloc[500:,-1])

# %% [markdown]
# # Image and Sound Data
#
# Inside a computer all data is numbers.

# %% [markdown]
# ## Images...
# record the intensity of light at each point on the microchip in the camera lens. This can be 1D (greyscale), 3D (e.g., red, green, blue), or multi-spectral (lots of other features such as infra-red spectrum, etc.)
#
# We can load and process images using Python.

# %%
#c = pl.imread('/home/marslast/Dropbox/Transfer/Teaching/DATA201/Labs/cute.jpg')
c = pl.imread('../../res/cute.jpeg')
print(c)

print(np.shape(c))
# Out:
# [[ 2  2  2 ...  8  7  6]
#  [ 2  2  2 ...  7  7  7]
#  [ 2  2  2 ...  7  7  7]
#  ...
#  [ 4  4  4 ... 16 18 41]
#  [ 3  3  3 ... 17 20 26]
#  [ 2  2  2 ... 18 24 22]]
# (429, 600)

# %%
# pl.imshow(c,cmap='gray')
pl.imshow(c,cmap='gray_r')

# %%
d = pl.imread('../../res/hakatere.jpeg')
print(d)
print(np.shape(d))
pl.imshow(d,cmap='gray')
# Out:
# [[[ 5  5  7]
#   [ 6  6  8]
#   [ 5  5  7]
#   ...
#   [31 38 30]
#   [21 28 21]
#   [11 18 11]]
#
#  [[ 5  5  7]
#   [ 6  6  8]
#   [ 6  6  8]
#   ...
#   [29 36 28]
#   [20 27 20]
#   [12 19 12]]
#
#  [[ 4  4  6]
#   [ 7  7  9]
#   [ 7  7  9]
#   ...
#   [24 31 23]
#   [17 24 17]
#   [12 19 12]]
#
#  ...
#
#  [[ 5  5  7]
#   [ 4  4  6]
#   [ 4  4  6]
#   ...
#   [12 12 12]
#   [12 12 12]
#   [16 16 16]]
#
#  [[ 5  5  7]
#   [ 5  5  7]
#   [ 4  4  6]
#   ...
#   [14 14 14]
#   [17 17 17]
#   [22 22 22]]
#
#  [[ 6  6  8]
#   [ 6  6  8]
#   [ 5  5  7]
#   ...
#   [16 16 16]
#   [20 20 20]
#   [27 27 27]]]
# (475, 400, 3)

# %% [markdown]
# ## Sound
# is a wave of sound pressure. We turn it into a computational representation by sampling the wave at regular time points, such as 36,000 times a second (36 kHz).

# %%
import wavio
s = wavio.read('../../res/tril1.wav')

# %%
print(s.data[:100].T)
pl.plot(s.data)
# Out:
# [[ -16   -8   10  -17   -8   26  -57  -47  -46   71   22   11   25  -11
#     39   11   40  -43    8   10   61   -5    6    9  -60  -41  -20  -45
#    -10   29   40    4  -33  -63   38  -22   -4   -2  -34   50  -63   19
#     16   -8  -45  -22    7  -44    8  -25  -17   42   59   24   45   71
#     40   -7    6    8  -24   38    6  -13   60   18   33   17  -46  -48
#    -39   25  -16  -26   13  -18   -7   24   -7  -77    7    0  -14  -22
#    -29   42  -46  -55  -16  -74  -47   29  -35  -26  -55  -16   -5 -137
#     -1  -62]]

# %% [markdown]
# We can turn sound into a histogram of power (a spectrogram) using the Fourier transform. This can be treated like an image.

# %%
pl.specgram(np.squeeze(s.data))
# Out:
# (array([[2.27591838e+05, 6.93586805e+04, 4.32589183e+05, ...,
#          9.93355656e+04, 8.71621178e+04, 5.33464293e+05],
#         [2.59327427e+05, 3.36184182e+05, 2.52345785e+05, ...,
#          2.85938768e+05, 1.25468603e+04, 6.06674932e+05],
#         [3.35406695e+04, 6.02677261e+04, 4.13482492e+04, ...,
#          8.44245470e+04, 4.72236492e+04, 7.69292162e+04],
#         ...,
#         [3.43050600e+02, 3.09876860e+01, 3.16686802e+02, ...,
#          1.29404488e+03, 6.59398973e+02, 7.11619006e+02],
#         [6.32181921e+02, 1.56029291e+02, 2.82908624e+01, ...,
#          6.79121720e+02, 5.35030445e+01, 6.09447671e+02],
#         [5.60054649e+02, 9.49720531e+01, 5.73251770e+00, ...,
#          4.37687927e+01, 1.19246887e+01, 3.28556330e+01]]),
#  array([0.       , 0.0078125, 0.015625 , 0.0234375, 0.03125  , 0.0390625,
#         0.046875 , 0.0546875, 0.0625   , 0.0703125, 0.078125 , 0.0859375,
#         0.09375  , 0.1015625, 0.109375 , 0.1171875, 0.125    , 0.1328125,
#         0.140625 , 0.1484375, 0.15625  , 0.1640625, 0.171875 , 0.1796875,
#         0.1875   , 0.1953125, 0.203125 , 0.2109375, 0.21875  , 0.2265625,
#         0.234375 , 0.2421875, 0.25     , 0.2578125, 0.265625 , 0.2734375,
#         0.28125  , 0.2890625, 0.296875 , 0.3046875, 0.3125   , 0.3203125,
#         0.328125 , 0.3359375, 0.34375  , 0.3515625, 0.359375 , 0.3671875,
#         0.375    , 0.3828125, 0.390625 , 0.3984375, 0.40625  , 0.4140625,
#         0.421875 , 0.4296875, 0.4375   , 0.4453125, 0.453125 , 0.4609375,
#         0.46875  , 0.4765625, 0.484375 , 0.4921875, 0.5      , 0.5078125,
#         0.515625 , 0.5234375, 0.53125  , 0.5390625, 0.546875 , 0.5546875,
#         0.5625   , 0.5703125, 0.578125 , 0.5859375, 0.59375  , 0.6015625,
#         0.609375 , 0.6171875, 0.625    , 0.6328125, 0.640625 , 0.6484375,
#         0.65625  , 0.6640625, 0.671875 , 0.6796875, 0.6875   , 0.6953125,
#         0.703125 , 0.7109375, 0.71875  , 0.7265625, 0.734375 , 0.7421875,
#         0.75     , 0.7578125, 0.765625 , 0.7734375, 0.78125  , 0.7890625,
#         0.796875 , 0.8046875, 0.8125   , 0.8203125, 0.828125 , 0.8359375,
#         0.84375  , 0.8515625, 0.859375 , 0.8671875, 0.875    , 0.8828125,
#         0.890625 , 0.8984375, 0.90625  , 0.9140625, 0.921875 , 0.9296875,
#         0.9375   , 0.9453125, 0.953125 , 0.9609375, 0.96875  , 0.9765625,
#         0.984375 , 0.9921875, 1.       ]),
#  array([6.4000e+01, 1.2800e+02, 1.9200e+02, ..., 7.2064e+04, 7.2128e+04,
#         7.2192e+04]),
#  <matplotlib.image.AxesImage at 0x7fb404a976a0>)

# %% [markdown]
# # Anscombe's dataset
#
# This has two purposes here:
#  - to explore a dataset and see how important plotting can be
#  - to see some basic NumPy syntax

# %%
data = np.array([
[10.0    ,8.04   ,10.0   ,9.14   ,10.0   ,7.46   ,8.0    ,6.58 ],
[8.0     ,6.95   ,8.0    ,8.14   ,8.0    ,6.77   ,8.0    ,5.76 ],
[13.0    ,7.58   ,13.0   ,8.74   ,13.0   ,12.74  ,8.0    ,7.71 ],
[9.0     ,8.81   ,9.0    ,8.77   ,9.0    ,7.11   ,8.0    ,8.84 ],
[11.0    ,8.33   ,11.0   ,9.26   ,11.0   ,7.81   ,8.0    ,8.47 ],
[14.0    ,9.96   ,14.0   ,8.10   ,14.0   ,8.84   ,8.0    ,7.04 ],
[6.0     ,7.24   ,6.0    ,6.13   ,6.0    ,6.08   ,8.0    ,5.25 ],
[4.0     ,4.26   ,4.0    ,3.10   ,4.0    ,5.39   ,19.0   ,12.50],
[12.0    ,10.84  ,12.0   ,9.13   ,12.0   ,8.15   ,8.0    ,5.56 ],
[7.0     ,4.82   ,7.0    ,7.26   ,7.0    ,6.42   ,8.0    ,7.91 ],
[5.0     ,5.68   ,5.0    ,4.74   ,5.0    ,5.73   ,8.0    ,6.89 ],
])

# %% [markdown]
# What are the basic statistics of these datasets?

# %%
# Out:
# array([9.        , 7.50090909, 9.        , 7.50090909, 9.        ,
#        7.5       , 9.        , 7.50090909])

# %%
# Out:
# array([3.16227766, 1.93702422, 3.16227766, 1.93710869, 3.16227766,
#        1.93593294, 3.16227766, 1.93608065])

# %%
# Out:
# [[1.         0.81642052]
#  [0.81642052 1.        ]]
# [[1.         0.81623651]
#  [0.81623651 1.        ]]
# [[1.         0.81628674]
#  [0.81628674 1.        ]]
# [[1.         0.81652144]
#  [0.81652144 1.        ]]

# %% [markdown]
# So are they all the same then?

# %%
pl.subplot(221)
pl.plot(data[0,:],data[1,:],'.',markersize=12)
pl.subplot(222)
pl.plot(data[2,:],data[3,:],'.',markersize=12)
pl.subplot(223)
pl.plot(data[4,:],data[5,:],'.',markersize=12)
pl.subplot(224)
pl.plot(data[6,:],data[7,:],'.',markersize=12)

# %%
print(np.polyfit(data[:,0],data[:,1],1))
print(np.polyfit(data[:,2],data[:,3],1))
print(np.polyfit(data[:,4],data[:,5],1))
print(np.polyfit(data[:,6],data[:,7],1))
# Out:
# [0.50009091 3.00009091]
# [0.5        3.00090909]
# [0.49972727 3.00245455]
# [0.49990909 3.00172727]
